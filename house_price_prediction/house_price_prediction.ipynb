# %%
# import needed libraries

import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as ptch
import numpy as np
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error
from sklearn.tree import DecisionTreeRegressor
from scipy import stats
from sklearn.feature_selection import mutual_info_regression

# %% [markdown]
# # 1. Data pre-processing and Preview

# %%
original_data = pd.read_csv('data.csv')

# %%
original_data.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
#    yr_renovated                    street       city  statezip country
# 0          2005      18810 Densmore Ave N  Shoreline  WA 98133     USA
# 1             0           709 W Blaine St    Seattle  WA 98119     USA
# 2             0  26206-26214 143rd Ave SE       Kent  WA 98042     USA
# 3             0           857 170th Pl NE   Bellevue  WA 98008     USA
# 4          1992         9105 170th Ave NE    Redmond  WA 98052     USA

# %% [markdown]
# ## 1.2 dropping some columns
# drop these columns: date, country, street
# - date and country are the same for all rows
# - street has high cardinality, so we just skip

# %%
data = original_data.drop(['date', 'street', 'country'], axis=1)

# %%
data.head()
# Out:
#        price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0   313000.0       3.0       1.50         1340      7912     1.5           0
# 1  2384000.0       5.0       2.50         3650      9050     2.0           0
# 2   342000.0       3.0       2.00         1930     11947     1.0           0
# 3   420000.0       3.0       2.25         2000      8030     1.0           0
# 4   550000.0       4.0       2.50         1940     10500     1.0           0
#
#    view  condition  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3        1340              0      1955          2005
# 1     4          5        3370            280      1921             0
# 2     0          4        1930              0      1966             0
# 3     0          4        1000           1000      1963             0
# 4     0          4        1140            800      1976          1992
#
#         city  statezip
# 0  Shoreline  WA 98133
# 1    Seattle  WA 98119
# 2       Kent  WA 98042
# 3   Bellevue  WA 98008
# 4    Redmond  WA 98052

# %% [markdown]
# ## 1.3 Feature removal based on the mutual information

# %%
features = list(data.columns[1:])
output = data['price'].values.reshape(-1, 1)
mir_result = {}
for col in features:    
    if data[col].dtype != np.float64 and data[col].dtype != np.int64:
        feature_factorized, _ = data[col].factorize() 
        m = mutual_info_regression(output, feature_factorized, random_state=0)
    else:
        m = mutual_info_regression(output, data[col], random_state=0)
    mir_result[col] = m

# %%
x = list(mir_result.keys())
y = [score[0] for score in list(mir_result.values())]
plt.figure(figsize=(10,6))
plt.barh(x, y)
plt.title("Mutual information regression between features and output (price)")
plt.xlabel("mutual information score")
plt.ylabel("Faetures")
red_patch= ptch.Patch(color="red", label="threshold")
plt.legend(handles=[red_patch], loc=4, prop={'size': 15})
plt.axvline(x=0.05, color="red")
plt.show()

# %%
# Remove features with threshold 0.05

threshold = 0.05
new_columns = []
for col,mir in mir_result.items():
    if mir > threshold:
        new_columns.append(col)
new_columns.append('price')
data = data[new_columns]

# %%
data.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  view  sqft_above  \
# 0       3.0       1.50         1340      7912     1.5     0        1340
# 1       5.0       2.50         3650      9050     2.0     4        3370
# 2       3.0       2.00         1930     11947     1.0     0        1930
# 3       3.0       2.25         2000      8030     1.0     0        1000
# 4       4.0       2.50         1940     10500     1.0     0        1140
#
#    sqft_basement  yr_built       city  statezip      price
# 0              0      1955  Shoreline  WA 98133   313000.0
# 1            280      1921    Seattle  WA 98119  2384000.0
# 2              0      1966       Kent  WA 98042   342000.0
# 3           1000      1963   Bellevue  WA 98008   420000.0
# 4            800      1976    Redmond  WA 98052   550000.0

# %% [markdown]
# ## 1.4 Outlier detection with Z-score

# %%
data.shape
# Out:
# (4600, 12)

# %%
columns = list(data.columns)
rows_to_drop = []
for col in columns:
    if data[col].dtype != np.float64 and data[col].dtype != np.int64:
        continue
    z_scores = stats.zscore(data[col])
    for i in range(len(z_scores)):
        if abs(z_scores[i]) > 3:
            rows_to_drop.append(i)

rows_to_drop = sorted(list(set(rows_to_drop)))
data = data.drop(rows_to_drop)
data.reset_index(drop=True, inplace=True)

# %%
data.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  view  sqft_above  \
# 0       3.0       1.50         1340      7912     1.5     0        1340
# 1       3.0       2.00         1930     11947     1.0     0        1930
# 2       3.0       2.25         2000      8030     1.0     0        1000
# 3       4.0       2.50         1940     10500     1.0     0        1140
# 4       2.0       1.00          880      6380     1.0     0         880
#
#    sqft_basement  yr_built       city  statezip     price
# 0              0      1955  Shoreline  WA 98133  313000.0
# 1              0      1966       Kent  WA 98042  342000.0
# 2           1000      1963   Bellevue  WA 98008  420000.0
# 3            800      1976    Redmond  WA 98052  550000.0
# 4              0      1938    Seattle  WA 98115  490000.0

# %%
data.shape
# Out:
# (4247, 12)

# %% [markdown]
# ## 1.5 Get Features and Dependent Variable

# %%
# seperate the Dependent (y) and Independent (X) variables

y = data.iloc[:, -1].values # price column
X = data.iloc[:, :-1].values

# %% [markdown]
# ## 1.6 Encoding

# %%
# City and Statezip are categorical. 

state_zip_index = list(data.columns).index("statezip")
city_index = list(data.columns).index("city")
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [city_index, state_zip_index])], remainder='passthrough')
X = ct.fit_transform(X)

# %% [markdown]
# ## 1.7 Split data

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1/4, random_state=1)

# %% [markdown]
# # 2. MultiLinear Regression

# %%
mlr = LinearRegression()
mlr.fit(X_train, y_train)
y_pred_mlr = mlr.predict(X_test)
r2_mlr = r2_score(y_test, y_pred_mlr)
mae_mlr = mean_absolute_error(y_test, y_pred_mlr)
print("R2 score for multi linear Regression:  {}".format(r2_mlr))
print("Mean Absolute Error for multi linear Regression:  {}".format(mae_mlr))
# Out:
# R2 score for multi linear Regression:  0.7572330052673701
# Mean Absolute Error for multi linear Regression:  82862.86077849456
